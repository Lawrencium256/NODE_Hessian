# %%
"""
--------------------------------------------------------------------------------------------------------------------------------------------
This code is simply used to execute other files via the "command line".
--------------------------------------------------------------------------------------------------------------------------------------------
"""

# %%
# %%bash
# pip install torchdiffeq

# %%
# %%bash
# cd drive/MyDrive/colab_notebooks
# jupyter nbconvert --to python NGD_spiral.ipynb

# %%
# %%bash
# cd drive/MyDrive/colab_notebooks
# python3 NGD_spiral.py --niters 1000 --viz --adjoint

# %%
# %%bash
# cd drive/MyDrive/colab_notebooks
# rm -r png

# %%
"""
--------------------------------------------------------------------------------------------------------------------------------------------
This code is used to add/edit files with the GitHub repository.
--------------------------------------------------------------------------------------------------------------------------------------------
"""

# %%
# %%bash
# cd /content
# cd drive/MyDrive/colab_notebooks
# git init
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/colab_notebooks/.git/

# %%
# %%bash
# cd drive/MyDrive/colab_notebooks
# git config --global user.name "Lawrencium256"
# git config --global user.email "la416@cam.ac.uk"
# git config --global --list
# Out:
# user.name=Lawrencium256
# user.email=la416@cam.ac.uk

# %%
# %%bash
# git clone https://github.com/Lawrencium256/NODE_Hessian.git
# Out:
# Cloning into 'NODE_Hessian'...
# fatal: could not read Username for 'https://github.com': No such device or address
