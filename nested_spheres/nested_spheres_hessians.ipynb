# %%
# %%capture
"""
-----------------------------------------------------------------------------------------------------------------------------------------------------------
This file is used to calculate Hessian information for a model during training for the nested N-spheres task.
-----------------------------------------------------------------------------------------------------------------------------------------------------------
"""

# %%
# %%capture
# %%bash 
pip install torchdiffeq

# %%
import os
import argparse
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--tol', type=float, default=1e-3)
parser.add_argument('--adjoint', type=eval, default=False)
parser.add_argument('--visualise', type=eval, default=True)
parser.add_argument('--niters', type=int, default=600)
parser.add_argument('--lr', type=float, default=0.01)
parser.add_argument('--gpu', type=int, default=0)
parser.add_argument('--extra_dim', type=int, default=1)
parser.add_argument('--data_dimension', type=int, default=2)
parser.add_argument('--npoints', type=int, default=50)
parser.add_argument('--ntest', type=int, default=10)
parser.add_argument('--hessian_freq', type=int, default=20)
parser.add_argument('--library_hessian', type=eval, default = False)
parser.add_argument('--manual_hessian', type=eval, default = False)
parser.add_argument('--mofd_hessian', type=eval, default = False)
args = parser.parse_args(args=[])

args.extra_dim = 0
args.library_hessian = True
args.manual_hessian = False
args.mofd_hessian = False

if args.adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

device = torch.device('cuda:' + str(args.gpu) if torch.cuda.is_available() else 'cpu')

# %%
class ODEfunc(nn.Module):
    """
    Neural network to parametrise the derivative of the state vector. Maps from [dim] to [dim] dimensions.
    """
    def __init__(self, dim, nhidden):
        super(ODEfunc, self).__init__()
        self.elu = nn.ELU(inplace=True)
        self.fc1 = nn.Linear(dim, nhidden)
        self.fc2 = nn.Linear(nhidden, nhidden)
        self.fc3 = nn.Linear(nhidden, dim)
        self.nfe = 0

    def forward(self, t, x):
        self.nfe += 1
        out = self.fc1(x)
        out = self.elu(out)
        out = self.fc2(out)
        out = self.elu(out)
        out = self.fc3(out)
        return out
    

class ODEBlock(nn.Module):
    """
    Defines the entire ODE block that acts on the state vector, i.e. it perfoms integration on the state vector
    with the derivative given by an ODEFunc() object, and interval given by [t0, tN].
    """
    def __init__(self, odefunc, t0_, tN_):
        super(ODEBlock, self).__init__()
        self.odefunc = odefunc
        self.integration_times = torch.tensor([t0_, tN_]).float()
        
    def forward(self, x):
        out = odeint(self.odefunc, x, self.integration_times, rtol=args.tol, atol=args.tol)
        out = out[1]
        return out

    @property
    def nfe(self):
        return self.odefunc.nfe

    @nfe.setter
    def nfe(self, value):
        self.odefunc.nfe = value

# %%
class Decoder(nn.Module):
    """
    Function that maps 2D output to a scalar (i.e. 1D vector). The output is then compared to the desired value
    (either 1 or -1).
    """
    def __init__(self, in_dim, out_dim):          #out_dim = 1.
        super(Decoder, self).__init__()
        self.tanh = nn.Hardtanh(min_val=-1.0, max_val=1.0, inplace=False)
        self.fc = nn.Linear(in_dim, out_dim)

    def forward(self, z):
        out = self.fc(z)
        out = self.tanh(out)
        return out


def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
class Network(nn.Module):
  """
  Neural network that is used for Hessian calculation with library-function and MOFD approaches.
  """

  def __init__(self, a, b, c, d, e, f):
    super(Network, self).__init__()
    self.a = a
    self.b = b
    self.c = c
    self.d = d
    self.e = e
    self.f = f

  def forward(self, t, y):
    m = nn.ELU(inplace=True)
    x = F.linear(y, self.a, self.b)
    x = m(x)
    x = F.linear(x, self.c, self.d)
    x = m(x)
    x = F.linear(x, self.e, self.f)

    return x

neural_net = Network()

# %%
class Integrator(nn.Module):
  """

  """
  def __init__(self, g, h, odefunc, t0, tN):
    super(Integrator, self).__init__()
    self.g = g
    self.h = h
    self.odefunc = odefunc
    self.integration_times = torch.tensor([t0, tN]).float()

  def forward(self, y):
    m = nn.Hardtanh(min_val=-1.0, max_val=1.0, inplace=False)
    x = odeint(self.odefunc, y, self.integration_times, rtol=args.tol, atol=args.tol)
    x = x[1]
    x = F.linear(x, self.g, self.h)
    x = m(x)
    return x

# %%
def get_loss(params_vector):

  a = params_vector[:nhidden*dim].reshape([nhidden, dim])
  b = params_vector[nhidden*dim:nhidden*(dim+1)].reshape([nhidden])
  c = params_vector[nhidden*(dim+1):nhidden*(dim+1)+nhidden**2].reshape([nhidden, nhidden])
  d = params_vector[nhidden*(dim+1)+nhidden**2:nhidden*(dim+2)+nhidden**2].reshape([nhidden])
  e = params_vector[nhidden*(dim+2)+nhidden**2:nhidden*(2*dim+2)+nhidden**2].reshape([dim,nhidden])
  f = params_vector[nhidden*(2*dim+2)+nhidden**2:nhidden*(2*dim+2)+nhidden**2+dim].reshape([dim])
  g = params_vector[nhidden*(2*dim+2)+nhidden**2+dim:nhidden*(2*dim+2)+nhidden**2+2*dim].reshape([1,dim])
  h = params_vector[nhidden*(2*dim+2)+nhidden**2+2*dim:nhidden*(2*dim+2)+nhidden**2+2*dim+1].reshape([1])
  
  neural_net = Network(a, b, c, d, e, f).to(device)
  full_block = Integrator(g, h, neural_net, t0, tN)
  pred_z = full_block(z0)
  loss_func = nn.MSELoss()
  loss = loss_func(pred_z, zN)
  return loss

def get_library_hessian(net):
  """
  Obtains the Hessian of the NODE using the autograd.functional.hessian() function.
  Inputs: 
        - net: the network for which the Hessian is to be calculated.
  NB: Each individual NODE architecture must be specified in the function get_loss(), such that
  the Hessian is calculated correctly.
  """

  param_tensors = net.parameters()
  params_vector = torch.tensor([]).to(device)
  for param in param_tensors:
    vec = torch.reshape(param, (-1,)).to(device)
    params_vector = torch.cat((params_vector, vec))

  hessian = torch.autograd.functional.hessian(get_loss, params_vector)
  return hessian

# %%
def get_manual_hessian(grads, parameters, show_iters=True):
  """
  Calculation of the Hessian using nested for loops.
  Inputs:   - grads:        tuple of gradient tensors. Created using something 
                            like grads = torch.autograd.grad(loss, parameters, create_graph=True).
            - parameters:   List of parameter objects. Created using something 
                            like parameters = optimizer.param_groups[0]['params'].
            - show_iters:   True or False, depending on if the iteration number is to be shown during training. 
                            Note that the iteration updates are not provided every row, but instead periodically 
                            (roughly according to the number of parameters in the system).
  """
  start = time.time()        

  n_params = 0
  for param in parameters:
    n_params += torch.numel(param)
  grads2 = torch.zeros(n_params,n_params)            #Create an matrix of zeros thas has the same shape as the Hessian.

  y_counter = 0                             #y_direction refers to row number in the Hessian.

  for grad in grads:
      grad = torch.reshape(grad, [-1])                                  #Rearrange the gradient information into a vector.        

      for j, g in enumerate(grad):
        x_counter = 0                                                   #x_direction refers to column number in the Hessian.

        for l, param in enumerate(parameters):
          g2 = torch.autograd.grad(g, param, retain_graph=True)[0]      #Calculate the gradient of an element of the gradient wrt one layer's parameters.
          g2 = torch.reshape(g2, [-1])                                  #Reshape this into a vector.
          len = g2.shape[0]                       
          grads2[j+y_counter, x_counter:x_counter+len] = g2             #Indexing ensures that the second order derivatives are placed in the correct positions.
          x_counter += len

      grads2 = grads2.to(device)
      y_counter += grad.shape[0]

      if show_iters:
        print("Gradients calculated for row number " + str(y_counter) + ".")
  
  print('Time used was ', time.time() - start)

  return grads2

# %%
def get_mofd_hessian_element(p_vec, shapes, base_loss, i, k, h=1e-4):
  """
  Calculates an individual element of the Hessian via the MOFD.
  Inputs: - p_vec:        the parameters of the network organized into a vector.
          - shapes:       a list of torch.Size() objects describing the shapes of each parameter group.
          - base_loss:    loss of the unperturbed system. Used in calculating diagonal Hessian elements.
          - h:            the size of the pertubation applied to each parameter.
          - i and k:      the indices of the element to be calculated.
          - show_iters:   True or False according to whether iteration number is to be displayed during calculation.

  Returns: - 'grad2':     torch.tensor() object containing the Hessian element H[i,k] = H[k,i].
  
  NB: This function adapts to network architecture automatically.
  The code is designed to convert all floats to 64-bit automatically.
  """
  loss_func = nn.MSELoss()

  #List of integers detailing the number of elements in each parameter group.
  nels = [int(torch.prod(torch.tensor(shape))) for shape in shapes]
  nels = torch.tensor(nels)
  nels = torch.cumsum(nels, dim=0)
  nels = nels.tolist()

  #Empty tensors to store mofd info and perturbed parameters.
  up_pert_p_vec = torch.zeros_like(p_vec).double()
  low_pert_p_vec = torch.zeros_like(p_vec).double()

  up_up_pert_p_vec = torch.zeros_like(p_vec).double()
  up_low_pert_p_vec = torch.zeros_like(p_vec).double()
  low_up_pert_p_vec = torch.zeros_like(p_vec).double()
  low_low_pert_p_vec = torch.zeros_like(p_vec).double()
    
  #Versions of the parameter vector to be perturbed.
  for j in range(len(p_vec)):
    up_pert_p_vec[j] = p_vec[j]
    low_pert_p_vec[j] = p_vec[j]
    
  #Calculate the diagonal elements.
  if k == i:
    up_pert_p_vec[k] += h
    low_pert_p_vec[k] -= h

    a_up = up_pert_p_vec[:nels[0]].reshape(shapes[0])
    b_up = up_pert_p_vec[nels[0]:nels[1]].reshape(shapes[1])
    c_up = up_pert_p_vec[nels[1]:nels[2]].reshape(shapes[2])
    d_up = up_pert_p_vec[nels[2]:nels[3]].reshape(shapes[3])
    e_up = up_pert_p_vec[nels[3]:nels[4]].reshape(shapes[4])
    f_up = up_pert_p_vec[nels[4]:nels[5]].reshape(shapes[5])
    g_up = up_pert_p_vec[nels[5]:nels[6]].reshape(shapes[6])
    h_up = up_pert_p_vec[nels[6]:nels[7]].reshape(shapes[7])

    a_low = low_pert_p_vec[:nels[0]].reshape(shapes[0])
    b_low = low_pert_p_vec[nels[0]:nels[1]].reshape(shapes[1])
    c_low = low_pert_p_vec[nels[1]:nels[2]].reshape(shapes[2])
    d_low = low_pert_p_vec[nels[2]:nels[3]].reshape(shapes[3])
    e_low = low_pert_p_vec[nels[3]:nels[4]].reshape(shapes[4])
    f_low = low_pert_p_vec[nels[4]:nels[5]].reshape(shapes[5])
    g_low = low_pert_p_vec[nels[5]:nels[6]].reshape(shapes[6])
    h_low = low_pert_p_vec[nels[6]:nels[7]].reshape(shapes[7])

    neural_net_up = Network(a_up, b_up, c_up, d_up, e_up, f_up).to(device)
    full_block = Integrator(g_up, h_up, neural_net_up, t0, tN)
    pred_z = full_block(z0.double())
    loss_func = nn.MSELoss()
    pert_loss_up = loss = loss_func(pred_z, zN.double())

    neural_net_low = Network(a_low, b_low, c_low, d_low, e_low, f_low).to(device)
    full_block = Integrator(g_low, h_low, neural_net_low, t0, tN)
    pred_z = full_block(z0.double())
    loss_func = nn.MSELoss()
    pert_loss_low = loss = loss_func(pred_z, zN.double())
    
    grad2 = ((pert_loss_up - 2*base_loss + pert_loss_low)/(h**2)).double()

  #Calculate the off-diagonal elements.
  if k > i:
    
    #Vectors to be perturbed (there are 4 of these).
    #They must be created individually for each k so that previous iterations do not affect the parameter values.
    for l in range(len(p_vec)):
      up_up_pert_p_vec[l] = p_vec[l]
      up_low_pert_p_vec[l] = p_vec[l]
      low_up_pert_p_vec[l] = p_vec[l]
      low_low_pert_p_vec[l] = p_vec[l]

    up_up_pert_p_vec[i] += h
    up_up_pert_p_vec[k] += h

    up_low_pert_p_vec[i] += h
    up_low_pert_p_vec[k] -= h

    low_up_pert_p_vec[i] -= h
    low_up_pert_p_vec[k] += h

    low_low_pert_p_vec[i] -= h
    low_low_pert_p_vec[k] -= h

    a_up_up = up_up_pert_p_vec[:nels[0]].reshape(shapes[0])
    b_up_up = up_up_pert_p_vec[nels[0]:nels[1]].reshape(shapes[1])
    c_up_up = up_up_pert_p_vec[nels[1]:nels[2]].reshape(shapes[2])
    d_up_up = up_up_pert_p_vec[nels[2]:nels[3]].reshape(shapes[3])
    e_up_up = up_up_pert_p_vec[nels[3]:nels[4]].reshape(shapes[4])
    f_up_up = up_up_pert_p_vec[nels[4]:nels[5]].reshape(shapes[5])
    g_up_up = up_up_pert_p_vec[nels[5]:nels[6]].reshape(shapes[6])
    h_up_up = up_up_pert_p_vec[nels[6]:nels[7]].reshape(shapes[7])

    a_up_low = up_low_pert_p_vec[:nels[0]].reshape(shapes[0])
    b_up_low = up_low_pert_p_vec[nels[0]:nels[1]].reshape(shapes[1])
    c_up_low = up_low_pert_p_vec[nels[1]:nels[2]].reshape(shapes[2])
    d_up_low = up_low_pert_p_vec[nels[2]:nels[3]].reshape(shapes[3])
    e_up_low = up_low_pert_p_vec[nels[3]:nels[4]].reshape(shapes[4])
    f_up_low = up_low_pert_p_vec[nels[4]:nels[5]].reshape(shapes[5])
    g_up_low = up_low_pert_p_vec[nels[5]:nels[6]].reshape(shapes[6])
    h_up_low = up_low_pert_p_vec[nels[6]:nels[7]].reshape(shapes[7])

    a_low_up = low_up_pert_p_vec[:nels[0]].reshape(shapes[0])
    b_low_up = low_up_pert_p_vec[nels[0]:nels[1]].reshape(shapes[1])
    c_low_up = low_up_pert_p_vec[nels[1]:nels[2]].reshape(shapes[2])
    d_low_up = low_up_pert_p_vec[nels[2]:nels[3]].reshape(shapes[3])
    e_low_up = low_up_pert_p_vec[nels[3]:nels[4]].reshape(shapes[4])
    f_low_up = low_up_pert_p_vec[nels[4]:nels[5]].reshape(shapes[5])
    g_low_up = low_up_pert_p_vec[nels[5]:nels[6]].reshape(shapes[6])
    h_low_up = low_up_pert_p_vec[nels[6]:nels[7]].reshape(shapes[7])

    a_low_low = low_low_pert_p_vec[:nels[0]].reshape(shapes[0])
    b_low_low = low_low_pert_p_vec[nels[0]:nels[1]].reshape(shapes[1])
    c_low_low = low_low_pert_p_vec[nels[1]:nels[2]].reshape(shapes[2])
    d_low_low = low_low_pert_p_vec[nels[2]:nels[3]].reshape(shapes[3])
    e_low_low = low_low_pert_p_vec[nels[3]:nels[4]].reshape(shapes[4])
    f_low_low = low_low_pert_p_vec[nels[4]:nels[5]].reshape(shapes[5])
    g_low_low = low_low_pert_p_vec[nels[5]:nels[6]].reshape(shapes[6])
    h_low_low = low_low_pert_p_vec[nels[6]:nels[7]].reshape(shapes[7])

    neural_net_up_up = Network(a_up_up, b_up_up, c_up_up, d_up_up, e_up_up, f_up_up).to(device)
    full_block = Integrator(g_up_up, h_up_up, neural_net_up_up, t0, tN)
    pred_z = full_block(z0.double())
    loss_func = nn.MSELoss()
    pert_loss_up_up = loss = loss_func(pred_z, zN.double())

    neural_net_up_low = Network(a_up_low, b_up_low, c_up_low, d_up_low, e_up_low, f_up_low).to(device)
    full_block = Integrator(g_up_low, h_up_low, neural_net_up_low, t0, tN)
    pred_z = full_block(z0.double())
    loss_func = nn.MSELoss()
    pert_loss_up_low = loss = loss_func(pred_z, zN.double())

    neural_net_low_up = Network(a_low_up, b_low_up, c_low_up, d_low_up, e_low_up, f_low_up).to(device)
    full_block = Integrator(g_low_up, h_low_up, neural_net_low_up, t0, tN)
    pred_z = full_block(z0.double())
    loss_func = nn.MSELoss()
    pert_loss_low_up = loss = loss_func(pred_z, zN.double())

    neural_net_low_low = Network(a_low_low, b_low_low, c_low_low, d_low_low, e_low_low, f_low_low).to(device)
    full_block = Integrator(g_low_low, h_low_low, neural_net_low_low, t0, tN)
    pred_z = full_block(z0.double())
    loss_func = nn.MSELoss()
    pert_loss_low_low = loss = loss_func(pred_z, zN.double())
    
    #MOFD formula to estimate second order gradient.
    grad2 = ((pert_loss_up_up - pert_loss_up_low - pert_loss_low_up + pert_loss_low_low)/(4*h**2)).double()

  return grad2

# %%
args.extra_dim = 1

#Download data
name_in = str(args.data_dimension)+'din_'+str(args.npoints)+'_train.npy'        #Only use the training data.
name_out = str(args.data_dimension)+'dout_'+str(args.npoints)+'_train.npy'
folder_name = '/content/drive/MyDrive/colab_notebooks/NODE_Hessian/nested_spheres/data/'
z0 = torch.tensor(np.load(folder_name+name_in)).float().to(device)
zN = torch.tensor(np.load(folder_name+name_out)).float().to(device)

#Augment z0
zeros = torch.zeros(args.npoints, args.extra_dim).float()
z0 = torch.cat((z0, zeros), dim=1).to(device)

dim = args.data_dimension + args.extra_dim
t0, tN = 0.0, 1.0
nhidden = 20
feature_layers = [ODEBlock(ODEfunc(dim, nhidden), t0, tN), Decoder(dim, 1)]
model = nn.Sequential(*feature_layers).to(device)

itr = 160 
model = torch.load('/content/drive/MyDrive/colab_notebooks/NODE_Hessian/nested_spheres/anode(1)/models/model_'
                  + str(itr) + '.pt')

# %%
#Get manual Hessian.
optimizer = optim.Adam(model.parameters())
optimizer.zero_grad()

pred_y = model(z0)
base_loss_func = nn.MSELoss()
base_loss = base_loss_func(pred_y, zN)
grads = torch.autograd.grad(base_loss, model.parameters(), create_graph=True)
parameters = optimizer.param_groups[0]['params']

print('Obtaining manual hessian...')
manual_hessian = get_manual_hessian(grads, parameters)           #get manual hessian.
# Out:
# Obtaining manual hessian...
# Gradients calculated for row number 60.
# Gradients calculated for row number 80.
# Gradients calculated for row number 480.
# Gradients calculated for row number 500.
# Gradients calculated for row number 560.
# Gradients calculated for row number 563.
# Gradients calculated for row number 566.
# Gradients calculated for row number 567.
# Time used was  34.6351842880249

# %%
library_hessian = get_library_hessian(model)

# %%
print(library_hessian[0,:10])
print(manual_hessian[0,:10])
# Out:
# tensor([ 0.1514,  0.2080,  0.2965,  0.0526,  0.2257,  0.4119, -0.2956, -0.3247,
#         -0.4472,  0.5800])
# tensor([ 0.0070,  0.0027, -0.0016,  0.0014,  0.0014, -0.0010, -0.0053, -0.0038,
#          0.0037, -0.0018])

# %%
e_l, v_l = torch.symeig(library_hessian)
e_ma, v_ma = torch.symeig(manual_hessian)

plt.hist(e_l, bins=150, color='Orange')
plt.title('Library Hessian')
plt.show()
plt.hist(e_ma, bins=150, color='Green')
plt.title('Manual Hessian')
plt.show()

# %%
#Get MOFD Hessian for a given model.
double_model = model.double()
optimizer = optim.Adam(model.parameters())
optimizer.zero_grad()

#Prepare loss for MOFD.
pred_y = model(z0.double()).double()
base_loss_func = nn.MSELoss()
base_loss = base_loss_func(pred_y, zN.double())

#Prepare shape information for MOFD.
shapes = []
for param in model.parameters():
  shapes.append(param.shape)

#Create vector of parameters.
param_tensors = double_model.parameters()
params_vec = torch.tensor([]).to(device)
for param in param_tensors:
  vec = torch.reshape(param, (-1,)).to(device)
  params_vec = torch.cat((params_vec, vec))

print(library_hessian[0,:10])

w = len(params_vec)
w=30
print('Getting Hessian with h = 1e-4')
counter = w*(w+1)/2
mofd_hessian = torch.zeros((w,w)).double()
for i in range(w):
  for k in range(w):

    #Only calculate for k >= i, in the same way as get_mofd_hessian_element().
    #Failing to do so yields UnboundLocalError since local variable, grad2, is referenced before assignment.
    if k >= i:                     
      element = get_mofd_hessian_element(params_vec, shapes, base_loss, i, k, h=1e-5)
      mofd_hessian[i,k] = element.item()    #.item() is required to prevent RAM growth.
      mofd_hessian[k,i] = element.item()
      counter -= 1
      print("Iterations remaining: " + str(int(counter)) + ', Element: ' + str("{:.4e}".format(element.item())), end = '\n')
print('')
# Out:
# tensor([ 0.1514,  0.2080,  0.2965,  0.0526,  0.2257,  0.4119, -0.2956, -0.3247,
#         -0.4472,  0.5800])
# Getting Hessian with h = 1e-4
# Iterations remaining: 464, Element: 1.5470e-01
# Iterations remaining: 463, Element: 2.1198e-01
# Iterations remaining: 462, Element: 2.9893e-01
# Iterations remaining: 461, Element: 5.2016e-02
# Iterations remaining: 460, Element: 2.3101e-01
# Iterations remaining: 459, Element: 4.1852e-01
# Iterations remaining: 458, Element: -2.9789e-01
# Iterations remaining: 457, Element: -3.2589e-01
# Iterations remaining: 456, Element: -4.4881e-01
# Iterations remaining: 455, Element: 5.8417e-01
# Iterations remaining: 454, Element: 6.4335e-01
# Iterations remaining: 453, Element: 8.6537e-01
# Iterations remaining: 452, Element: 1.6062e-02
# Iterations remaining: 451, Element: 1.9185e-02
# Iterations remaining: 450, Element: 2.0469e-02
# Iterations remaining: 449, Element: -3.8328e-01
# Iterations remaining: 448, Element: -1.3829e-01
# Iterations remaining: 447, Element: -2.9012e-03
# Iterations remaining: 446, Element: 3.6516e-01
# Iterations remaining: 445, Element: 3.3197e-01
# Iterations remaining: 444, Element: 3.7929e-01
# Iterations remaining: 443, Element: 4.5510e-01
# Iterations remaining: 442, Element: 2.9949e-01
# Iterations remaining: 441, Element: 2.5601e-01
# Iterations remaining: 440, Element: 1.1098e-02
# Iterations remaining: 439, Element: -6.2735e-02
# Iterations remaining: 438, Element: -1.2466e-01
# Iterations remaining: 437, Element: -5.6818e-01
# Iterations remaining: 436, Element: -5.2938e-01
# Iterations remaining: 435, Element: -6.3113e-01
# Iterations remaining: 434, Element: 2.7983e-01
# Iterations remaining: 433, Element: 3.6614e-01
# Iterations remaining: 432, Element: 3.7662e-02
# Iterations remaining: 431, Element: 3.0942e-01
# Iterations remaining: 430, Element: 5.3813e-01
# Iterations remaining: 429, Element: -3.8456e-01
# Iterations remaining: 428, Element: -4.3643e-01
# Iterations remaining: 427, Element: -5.6742e-01
# Iterations remaining: 426, Element: 7.2277e-01
# Iterations remaining: 425, Element: 8.8808e-01
# Iterations remaining: 424, Element: 1.1431e+00
# Iterations remaining: 423, Element: 4.2803e-02
# Iterations remaining: 422, Element: 3.1386e-02
# Iterations remaining: 421, Element: 2.0785e-02
# Iterations remaining: 420, Element: -4.7838e-01
# Iterations remaining: 419, Element: -1.8049e-01
# Iterations remaining: 418, Element: -1.6456e-02
# Iterations remaining: 417, Element: 4.8400e-01
# Iterations remaining: 416, Element: 4.4389e-01
# Iterations remaining: 415, Element: 4.7707e-01
# Iterations remaining: 414, Element: 6.0121e-01
# Iterations remaining: 413, Element: 4.0970e-01
# Iterations remaining: 412, Element: 3.3136e-01
# Iterations remaining: 411, Element: -5.7608e-03
# Iterations remaining: 410, Element: -7.7921e-02
# Iterations remaining: 409, Element: -1.3869e-01
# Iterations remaining: 408, Element: -6.9458e-01
# Iterations remaining: 407, Element: -7.0528e-01
# Iterations remaining: 406, Element: -8.1276e-01
# Iterations remaining: 405, Element: 4.4377e-01
# Iterations remaining: 404, Element: 7.9531e-02
# Iterations remaining: 403, Element: 4.0750e-01
# Iterations remaining: 402, Element: 6.6171e-01
# Iterations remaining: 401, Element: -5.3269e-01
# Iterations remaining: 400, Element: -5.7553e-01
# Iterations remaining: 399, Element: -6.9205e-01
# Iterations remaining: 398, Element: 1.0168e+00
# Iterations remaining: 397, Element: 1.1868e+00
# Iterations remaining: 396, Element: 1.4258e+00
# Iterations remaining: 395, Element: 5.3412e-02
# Iterations remaining: 394, Element: 3.7623e-02
# Iterations remaining: 393, Element: 2.3490e-02
# Iterations remaining: 392, Element: -6.3823e-01
# Iterations remaining: 391, Element: -2.5150e-01
# Iterations remaining: 390, Element: -3.1897e-02
# Iterations remaining: 389, Element: 6.6172e-01
# Iterations remaining: 388, Element: 5.8633e-01
# Iterations remaining: 387, Element: 5.8770e-01
# Iterations remaining: 386, Element: 7.9943e-01
# Iterations remaining: 385, Element: 5.4074e-01
# Iterations remaining: 384, Element: 4.1355e-01
# Iterations remaining: 383, Element: -1.6839e-02
# Iterations remaining: 382, Element: -9.3625e-02
# Iterations remaining: 381, Element: -1.5662e-01
# Iterations remaining: 380, Element: -9.5529e-01
# Iterations remaining: 379, Element: -9.3344e-01
# Iterations remaining: 378, Element: -1.0066e+00
# Iterations remaining: 377, Element: -1.7507e-03
# Iterations remaining: 376, Element: 2.4600e-02
# Iterations remaining: 375, Element: 1.0814e-01
# Iterations remaining: 374, Element: -1.0894e-01
# Iterations remaining: 373, Element: -5.6993e-02
# Iterations remaining: 372, Element: -1.1196e-01
# Iterations remaining: 371, Element: 1.8526e-01
# Iterations remaining: 370, Element: 1.0385e-01
# Iterations remaining: 369, Element: 2.1755e-01
# Iterations remaining: 368, Element: 1.1168e-03
# Iterations remaining: 367, Element: -2.3881e-03
# Iterations remaining: 366, Element: -1.5152e-03
# Iterations remaining: 365, Element: -1.3960e-01
# Iterations remaining: 364, Element: -4.6039e-02
# Iterations remaining: 363, Element: -1.9184e-03
# Iterations remaining: 362, Element: 1.1788e-01
# Iterations remaining: 361, Element: 6.2016e-02
# Iterations remaining: 360, Element: 9.7784e-02
# Iterations remaining: 359, Element: 1.4900e-01
# Iterations remaining: 358, Element: 6.1797e-02
# Iterations remaining: 357, Element: 6.1137e-02
# Iterations remaining: 356, Element: -4.0054e-03
# Iterations remaining: 355, Element: -9.8205e-03
# Iterations remaining: 354, Element: -2.9584e-02
# Iterations remaining: 353, Element: -1.9345e-01
# Iterations remaining: 352, Element: -1.1038e-01
# Iterations remaining: 351, Element: -1.7296e-01
# Iterations remaining: 350, Element: 3.2083e-01
# Iterations remaining: 349, Element: 5.7407e-01
# Iterations remaining: 348, Element: -4.1723e-01
# Iterations remaining: 347, Element: -4.7650e-01
# Iterations remaining: 346, Element: -6.2664e-01
# Iterations remaining: 345, Element: 7.8640e-01
# Iterations remaining: 344, Element: 9.4816e-01
# Iterations remaining: 343, Element: 1.2375e+00
# Iterations remaining: 342, Element: 4.7403e-02
# Iterations remaining: 341, Element: 4.4945e-02
# Iterations remaining: 340, Element: 3.3516e-02
# Iterations remaining: 339, Element: -5.2416e-01
# Iterations remaining: 338, Element: -1.9033e-01
# Iterations remaining: 337, Element: -2.0614e-02
# Iterations remaining: 336, Element: 5.2719e-01
# Iterations remaining: 335, Element: 4.8798e-01
# Iterations remaining: 334, Element: 5.3157e-01
# Iterations remaining: 333, Element: 6.6085e-01
# Iterations remaining: 332, Element: 4.5492e-01
# Iterations remaining: 331, Element: 3.7608e-01
# Iterations remaining: 330, Element: -7.6293e-03
# Iterations remaining: 329, Element: -9.3307e-02
# Iterations remaining: 328, Element: -1.5596e-01
# Iterations remaining: 327, Element: -7.5021e-01
# Iterations remaining: 326, Element: -7.5668e-01
# Iterations remaining: 325, Element: -8.8195e-01
# Iterations remaining: 324, Element: 9.4066e-01
# Iterations remaining: 323, Element: -7.4417e-01
# Iterations remaining: 322, Element: -8.3905e-01
# Iterations remaining: 321, Element: -1.0209e+00
# Iterations remaining: 320, Element: 1.4449e+00
# Iterations remaining: 319, Element: 1.6914e+00
# Iterations remaining: 318, Element: 2.0421e+00
# Iterations remaining: 317, Element: 7.1767e-02
# Iterations remaining: 316, Element: 6.4953e-02
# Iterations remaining: 315, Element: 5.4131e-02
# Iterations remaining: 314, Element: -9.0092e-01
# Iterations remaining: 313, Element: -3.5522e-01
# Iterations remaining: 312, Element: -4.4083e-02
# Iterations remaining: 311, Element: 9.3275e-01
# Iterations remaining: 310, Element: 8.5377e-01
# Iterations remaining: 309, Element: 8.7101e-01
# Iterations remaining: 308, Element: 1.1333e+00
# Iterations remaining: 307, Element: 7.8649e-01
# Iterations remaining: 306, Element: 6.2017e-01
# Iterations remaining: 305, Element: -1.4367e-02
# Iterations remaining: 304, Element: -1.4360e-01
# Iterations remaining: 303, Element: -2.4234e-01
# Iterations remaining: 302, Element: -1.3478e+00
# Iterations remaining: 301, Element: -1.3289e+00
# Iterations remaining: 300, Element: -1.4459e+00
# Iterations remaining: 299, Element: 6.9758e-01
# Iterations remaining: 298, Element: 6.9842e-01
# Iterations remaining: 297, Element: 8.7084e-01
# Iterations remaining: 296, Element: -9.2613e-01
# Iterations remaining: 295, Element: -1.1097e+00
# Iterations remaining: 294, Element: -1.5436e+00
# Iterations remaining: 293, Element: -5.2455e-02
# Iterations remaining: 292, Element: -4.4247e-02
# Iterations remaining: 291, Element: -3.9361e-02
# Iterations remaining: 290, Element: 5.6399e-01
# Iterations remaining: 289, Element: 2.0097e-01
# Iterations remaining: 288, Element: -1.4975e-03
# Iterations remaining: 287, Element: -6.3942e-01
# Iterations remaining: 286, Element: -5.8762e-01
# Iterations remaining: 285, Element: -6.8036e-01
# Iterations remaining: 284, Element: -7.6171e-01
# Iterations remaining: 283, Element: -5.1539e-01
# Iterations remaining: 282, Element: -4.5690e-01
# Iterations remaining: 281, Element: -5.3766e-03
# Iterations remaining: 280, Element: 1.1564e-01
# Iterations remaining: 279, Element: 2.2164e-01
# Iterations remaining: 278, Element: 9.3254e-01
# Iterations remaining: 277, Element: 9.1904e-01
# Iterations remaining: 276, Element: 1.1304e+00
# Iterations remaining: 275, Element: 7.6140e-01
# Iterations remaining: 274, Element: 9.7619e-01
# Iterations remaining: 273, Element: -1.0790e+00
# Iterations remaining: 272, Element: -1.3455e+00
# Iterations remaining: 271, Element: -1.7622e+00
# Iterations remaining: 270, Element: -6.8302e-02
# Iterations remaining: 269, Element: -5.0789e-02
# Iterations remaining: 268, Element: -3.8188e-02
# Iterations remaining: 267, Element: 7.1011e-01
# Iterations remaining: 266, Element: 2.6942e-01
# Iterations remaining: 265, Element: 1.6908e-02
# Iterations remaining: 264, Element: -7.3526e-01
# Iterations remaining: 263, Element: -6.8446e-01
# Iterations remaining: 262, Element: -7.4510e-01
# Iterations remaining: 261, Element: -9.1024e-01
# Iterations remaining: 260, Element: -6.2524e-01
# Iterations remaining: 259, Element: -5.1368e-01
# Iterations remaining: 258, Element: 4.1595e-03
# Iterations remaining: 257, Element: 1.2049e-01
# Iterations remaining: 256, Element: 2.2125e-01
# Iterations remaining: 255, Element: 1.0404e+00
# Iterations remaining: 254, Element: 1.0744e+00
# Iterations remaining: 253, Element: 1.2606e+00
# Iterations remaining: 252, Element: 1.1839e+00
# Iterations remaining: 251, Element: -1.5550e+00
# Iterations remaining: 250, Element: -1.8115e+00
# Iterations remaining: 249, Element: -2.1757e+00
# Iterations remaining: 248, Element: -7.9935e-02
# Iterations remaining: 247, Element: -6.3411e-02
# Iterations remaining: 246, Element: -4.3143e-02
# Iterations remaining: 245, Element: 9.8370e-01
# Iterations remaining: 244, Element: 3.8038e-01
# Iterations remaining: 243, Element: 4.1945e-02
# Iterations remaining: 242, Element: -1.0064e+00
# Iterations remaining: 241, Element: -9.0269e-01
# Iterations remaining: 240, Element: -9.0757e-01
# Iterations remaining: 239, Element: -1.2257e+00
# Iterations remaining: 238, Element: -8.3195e-01
# Iterations remaining: 237, Element: -6.3579e-01
# Iterations remaining: 236, Element: 1.9190e-02
# Iterations remaining: 235, Element: 1.4918e-01
# Iterations remaining: 234, Element: 2.4805e-01
# Iterations remaining: 233, Element: 1.4533e+00
# Iterations remaining: 232, Element: 1.4281e+00
# Iterations remaining: 231, Element: 1.5419e+00
# Iterations remaining: 230, Element: 1.2827e+00
# Iterations remaining: 229, Element: 1.8684e+00
# Iterations remaining: 228, Element: 2.9205e+00
# Iterations remaining: 227, Element: 1.1734e-01
# Iterations remaining: 226, Element: 8.2293e-02
# Iterations remaining: 225, Element: 6.5938e-02
# Iterations remaining: 224, Element: -1.0161e+00
# Iterations remaining: 223, Element: -3.5753e-01
# Iterations remaining: 222, Element: 4.4316e-03
# Iterations remaining: 221, Element: 1.2136e+00
# Iterations remaining: 220, Element: 1.0972e+00
# Iterations remaining: 219, Element: 1.3024e+00
# Iterations remaining: 218, Element: 1.4289e+00
# Iterations remaining: 217, Element: 9.5950e-01
# Iterations remaining: 216, Element: 8.7192e-01
# Iterations remaining: 215, Element: -2.0550e-02
# Iterations remaining: 214, Element: -2.1610e-01
# Iterations remaining: 213, Element: -4.0937e-01
# Iterations remaining: 212, Element: -1.7194e+00
# Iterations remaining: 211, Element: -1.7261e+00
# Iterations remaining: 210, Element: -2.1936e+00
# Iterations remaining: 209, Element: 2.5431e+00
# Iterations remaining: 208, Element: 3.5142e+00
# Iterations remaining: 207, Element: 1.4098e-01
# Iterations remaining: 206, Element: 1.1492e-01
# Iterations remaining: 205, Element: 9.1893e-02
# Iterations remaining: 204, Element: -1.3531e+00
# Iterations remaining: 203, Element: -5.0265e-01
# Iterations remaining: 202, Element: -2.6248e-02
# Iterations remaining: 201, Element: 1.4381e+00
# Iterations remaining: 200, Element: 1.3730e+00
# Iterations remaining: 199, Element: 1.5284e+00
# Iterations remaining: 198, Element: 1.7761e+00
# Iterations remaining: 197, Element: 1.2425e+00
# Iterations remaining: 196, Element: 1.0550e+00
# Iterations remaining: 195, Element: -9.8076e-03
# Iterations remaining: 194, Element: -2.6041e-01
# Iterations remaining: 193, Element: -4.6699e-01
# Iterations remaining: 192, Element: -2.0146e+00
# Iterations remaining: 191, Element: -2.1271e+00
# Iterations remaining: 190, Element: -2.5497e+00
# Iterations remaining: 189, Element: 4.3308e+00
# Iterations remaining: 188, Element: 1.5100e-01
# Iterations remaining: 187, Element: 1.3532e-01
# Iterations remaining: 186, Element: 1.1060e-01
# Iterations remaining: 185, Element: -1.8843e+00
# Iterations remaining: 184, Element: -7.2771e-01
# Iterations remaining: 183, Element: -7.1355e-02
# Iterations remaining: 182, Element: 1.9439e+00
# Iterations remaining: 181, Element: 1.7971e+00
# Iterations remaining: 180, Element: 1.8546e+00
# Iterations remaining: 179, Element: 2.3688e+00
# Iterations remaining: 178, Element: 1.6408e+00
# Iterations remaining: 177, Element: 1.2984e+00
# Iterations remaining: 176, Element: -1.9214e-02
# Iterations remaining: 175, Element: -3.1150e-01
# Iterations remaining: 174, Element: -5.3334e-01
# Iterations remaining: 173, Element: -2.8051e+00
# Iterations remaining: 172, Element: -2.8060e+00
# Iterations remaining: 171, Element: -3.0923e+00
# Iterations remaining: 170, Element: -3.6244e-03
# Iterations remaining: 169, Element: 3.5506e-03
# Iterations remaining: 168, Element: 3.9534e-03
# Iterations remaining: 167, Element: -9.5280e-02
# Iterations remaining: 166, Element: -3.4533e-02
# Iterations remaining: 165, Element: -1.6704e-03
# Iterations remaining: 164, Element: 5.9635e-02
# Iterations remaining: 163, Element: 6.9175e-02
# Iterations remaining: 162, Element: 6.6238e-02
# Iterations remaining: 161, Element: 8.5083e-02
# Iterations remaining: 160, Element: 6.3471e-02
# Iterations remaining: 159, Element: 4.4797e-02
# Iterations remaining: 158, Element: 8.6176e-03
# Iterations remaining: 157, Element: -1.5332e-02
# Iterations remaining: 156, Element: -2.6057e-02
# Iterations remaining: 155, Element: -1.0609e-01
# Iterations remaining: 154, Element: -1.0860e-01
# Iterations remaining: 153, Element: -1.0543e-01
# Iterations remaining: 152, Element: 4.6225e-03
# Iterations remaining: 151, Element: -2.0701e-03
# Iterations remaining: 150, Element: -6.9737e-02
# Iterations remaining: 149, Element: -1.6701e-02
# Iterations remaining: 148, Element: -1.7167e-03
# Iterations remaining: 147, Element: 5.3144e-02
# Iterations remaining: 146, Element: 5.1683e-02
# Iterations remaining: 145, Element: 5.0018e-02
# Iterations remaining: 144, Element: 7.2995e-02
# Iterations remaining: 143, Element: 4.6997e-02
# Iterations remaining: 142, Element: 3.0629e-02
# Iterations remaining: 141, Element: 1.3359e-04
# Iterations remaining: 140, Element: -1.2396e-02
# Iterations remaining: 139, Element: -1.4987e-02
# Iterations remaining: 138, Element: -8.0279e-02
# Iterations remaining: 137, Element: -9.1793e-02
# Iterations remaining: 136, Element: -9.6042e-02
# Iterations remaining: 135, Element: -6.6590e-03
# Iterations remaining: 134, Element: -5.6216e-02
# Iterations remaining: 133, Element: -2.1430e-02
# Iterations remaining: 132, Element: -2.8917e-03
# Iterations remaining: 131, Element: 4.7595e-02
# Iterations remaining: 130, Element: 3.6775e-02
# Iterations remaining: 129, Element: 3.3309e-02
# Iterations remaining: 128, Element: 6.1061e-02
# Iterations remaining: 127, Element: 3.3768e-02
# Iterations remaining: 126, Element: 1.7632e-02
# Iterations remaining: 125, Element: -1.4364e-03
# Iterations remaining: 124, Element: -3.4738e-03
# Iterations remaining: 123, Element: -6.5650e-03
# Iterations remaining: 122, Element: -6.7011e-02
# Iterations remaining: 121, Element: -7.2801e-02
# Iterations remaining: 120, Element: -7.6997e-02
# Iterations remaining: 119, Element: 5.5750e-01
# Iterations remaining: 118, Element: 1.9909e-01
# Iterations remaining: 117, Element: -2.3874e-03
# Iterations remaining: 116, Element: -7.6514e-01
# Iterations remaining: 115, Element: -7.1929e-01
# Iterations remaining: 114, Element: -8.2549e-01
# Iterations remaining: 113, Element: -8.7738e-01
# Iterations remaining: 112, Element: -6.2596e-01
# Iterations remaining: 111, Element: -5.6740e-01
# Iterations remaining: 110, Element: 2.1689e-02
# Iterations remaining: 109, Element: 1.4317e-01
# Iterations remaining: 108, Element: 2.5494e-01
# Iterations remaining: 107, Element: 1.0391e+00
# Iterations remaining: 106, Element: 1.1091e+00
# Iterations remaining: 105, Element: 1.3732e+00
# Iterations remaining: 104, Element: 9.3687e-02
# Iterations remaining: 103, Element: -4.7553e-03
# Iterations remaining: 102, Element: -2.7622e-01
# Iterations remaining: 101, Element: -2.6940e-01
# Iterations remaining: 100, Element: -3.1985e-01
# Iterations remaining: 99, Element: -3.1740e-01
# Iterations remaining: 98, Element: -2.2961e-01
# Iterations remaining: 97, Element: -2.1651e-01
# Iterations remaining: 96, Element: 1.3869e-03
# Iterations remaining: 95, Element: 4.4925e-02
# Iterations remaining: 94, Element: 1.0256e-01
# Iterations remaining: 93, Element: 3.7124e-01
# Iterations remaining: 92, Element: 4.0859e-01
# Iterations remaining: 91, Element: 5.2895e-01
# Iterations remaining: 90, Element: -8.2332e-03
# Iterations remaining: 89, Element: -6.1506e-03
# Iterations remaining: 88, Element: -1.7655e-02
# Iterations remaining: 87, Element: -3.4187e-02
# Iterations remaining: 86, Element: -6.2870e-03
# Iterations remaining: 85, Element: -8.3729e-03
# Iterations remaining: 84, Element: -1.7755e-02
# Iterations remaining: 83, Element: -4.8318e-03
# Iterations remaining: 82, Element: 7.6848e-03
# Iterations remaining: 81, Element: 1.7570e-02
# Iterations remaining: 80, Element: 7.5533e-03
# Iterations remaining: 79, Element: 2.3977e-02
# Iterations remaining: 78, Element: 5.2994e-02
# Iterations remaining: 77, Element: 8.0698e-01
# Iterations remaining: 76, Element: 7.4542e-01
# Iterations remaining: 75, Element: 8.4852e-01
# Iterations remaining: 74, Element: 9.8629e-01
# Iterations remaining: 73, Element: 6.6825e-01
# Iterations remaining: 72, Element: 5.7700e-01
# Iterations remaining: 71, Element: 3.5926e-03
# Iterations remaining: 70, Element: -1.4375e-01
# Iterations remaining: 69, Element: -2.6912e-01
# Iterations remaining: 68, Element: -1.2025e+00
# Iterations remaining: 67, Element: -1.1781e+00
# Iterations remaining: 66, Element: -1.4126e+00
# Iterations remaining: 65, Element: 6.9452e-01
# Iterations remaining: 64, Element: 7.5985e-01
# Iterations remaining: 63, Element: 9.2446e-01
# Iterations remaining: 62, Element: 6.3489e-01
# Iterations remaining: 61, Element: 5.2358e-01
# Iterations remaining: 60, Element: -7.1590e-03
# Iterations remaining: 59, Element: -1.2715e-01
# Iterations remaining: 58, Element: -2.2782e-01
# Iterations remaining: 57, Element: -1.0659e+00
# Iterations remaining: 56, Element: -1.0969e+00
# Iterations remaining: 55, Element: -1.2843e+00
# Iterations remaining: 54, Element: 7.6874e-01
# Iterations remaining: 53, Element: 1.0285e+00
# Iterations remaining: 52, Element: 6.9683e-01
# Iterations remaining: 51, Element: 5.3737e-01
# Iterations remaining: 50, Element: -1.4767e-02
# Iterations remaining: 49, Element: -1.2599e-01
# Iterations remaining: 48, Element: -2.1441e-01
# Iterations remaining: 47, Element: -1.2264e+00
# Iterations remaining: 46, Element: -1.2067e+00
# Iterations remaining: 45, Element: -1.3142e+00
# Iterations remaining: 44, Element: 1.1618e+00
# Iterations remaining: 43, Element: 8.3490e-01
# Iterations remaining: 42, Element: 7.4128e-01
# Iterations remaining: 41, Element: -4.5132e-03
# Iterations remaining: 40, Element: -1.8032e-01
# Iterations remaining: 39, Element: -3.2490e-01
# Iterations remaining: 38, Element: -1.4243e+00
# Iterations remaining: 37, Element: -1.4479e+00
# Iterations remaining: 36, Element: -1.7162e+00
# Iterations remaining: 35, Element: 5.2535e-01
# Iterations remaining: 34, Element: 4.3211e-01
# Iterations remaining: 33, Element: -2.0409e-03
# Iterations remaining: 32, Element: -1.2031e-01
# Iterations remaining: 31, Element: -2.1679e-01
# Iterations remaining: 30, Element: -9.4612e-01
# Iterations remaining: 29, Element: -9.9986e-01
# Iterations remaining: 28, Element: -1.1809e+00
# Iterations remaining: 27, Element: 2.7660e-01
# Iterations remaining: 26, Element: -3.2557e-03
# Iterations remaining: 25, Element: -8.9773e-02
# Iterations remaining: 24, Element: -1.5815e-01
# Iterations remaining: 23, Element: -8.3431e-01
# Iterations remaining: 22, Element: -8.3951e-01
# Iterations remaining: 21, Element: -9.2671e-01
# Iterations remaining: 20, Element: 4.9737e-03
# Iterations remaining: 19, Element: 4.5156e-03
# Iterations remaining: 18, Element: -4.7501e-03
# Iterations remaining: 17, Element: 1.4878e-02
# Iterations remaining: 16, Element: 1.0856e-02
# Iterations remaining: 15, Element: 1.8188e-02
# Iterations remaining: 14, Element: 4.5535e-02
# Iterations remaining: 13, Element: 7.7581e-02
# Iterations remaining: 12, Element: 2.0387e-01
# Iterations remaining: 11, Element: 2.0487e-01
# Iterations remaining: 10, Element: 2.1932e-01
# Iterations remaining: 9, Element: 1.3431e-01
# Iterations remaining: 8, Element: 3.8191e-01
# Iterations remaining: 7, Element: 3.6409e-01
# Iterations remaining: 6, Element: 3.7214e-01
# Iterations remaining: 5, Element: 2.1048e+00
# Iterations remaining: 4, Element: 1.8728e+00
# Iterations remaining: 3, Element: 2.1550e+00
# Iterations remaining: 2, Element: 1.8476e+00
# Iterations remaining: 1, Element: 2.1170e+00
# Iterations remaining: 0, Element: 2.3008e+00

# %%
difference = 0
differences = []
for i in range(w):
  for k in range(w):
    if k >= i:
      difference += torch.abs(mofd_hessian[i,k]-library_hessian[i,k]).item()
      differences.append((torch.abs(mofd_hessian[i,k]-library_hessian[i,k]).item()))

print(difference)
print(np.amax(differences))
plt.hist(differences, bins = 150)
plt.show()
# Out:
# 2.664886901661087
# 0.045209473343639894
